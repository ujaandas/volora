# %%
import pyaudio
import wave
import soxbindings as sox

# %%
CHUNK = 1024
FORMAT = pyaudio.paInt16 # 16 bits per sample
CHANNELS = 1
RATE = 44100 # 44.1k samples/sec # try 500 for 8k bitrate
# RATE = 500
RECORD_SECONDS = 5 # 3s
WAVE_OUTPUT_FILENAME = "input.wav"

# total samples = RATE * RECORD_SECONDS = 44100 * 3 = 132300
# total bits = total samples * 16 bits = 132300 * 16 = 2116800
# bitrate = total bits / total seconds = 2116800 / 3 = 705600

# %%
p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()
# Out:
# * recording
# * done recording

# %%
print(frames)
print(len(frames))
# print number of bits
print(len(frames[0]))
# print number of bytes
print(len(frames[0]) / 8)
# Out:
# [b'\x00\x00\x00\x00\x00\x00\xee\xff\x87\xff^\xfe\xdc\xfcY\xfc\xab\xfc\x85\xfc\x80\xfc\xd7\xfc\xb8\xfc\xd8\xfc\xfa\xfc\xe7\xfc\x1b\xfd\x00\xfd\x08\xfd\x1a\xfd\x1c\xfdL\xfdC\xfdt\xfd\x94\xfd\xc1\xfd\xfd\xfd\x1b\xfeT\xfeo\xfe\xab\xfe\xbc\xfe\xcd\xfe\xdd\xfe\xe6\xfe\xf3\xfe\xd4\xfe\xd1\xfe\xbc\xfe\xb7\xfe\x9f\xfe\x8d\xfe\x85\xfe~\xfe\x91\xfe\x8c\xfe\xa4\xfe\xb8\xfe\xee\xfe\x1f\xffO\xff\x83\xff\xb8\xff\xfa\xff1\x00x\x00\xab\x00\xed\x00!\x01P\x01n\x01\x8a\x01\xaa\x01\xb0\x01\xbc\x01\xb5\x01\xc7\x01\xd8\x01\xf3\x01\x0e\x023\x02b\x02\x90\x02\xc1\x02\xe7\x021\x03o\x03\xae\x03\xe2\x03\x18\x04E\x04h\x04\x84\x04\x8f\x04\xa5\x04\xae\x04\xbb\x04\xbd\x04\xc5\x04\xc9\x04\xc7\x04\xc1\x04\xb6\x04\xa9\x04\xa0\x04\x92\x04w\x04j\x04N\x04<\x04$\x04\x0e\x04\xfe\x03\xf6\x03\xf8\x03\xf0\x03\xf1\x03\xf0\x03\xf4\x03\xed\x03\xe5\x03\xd9\x03\xd1\x03\xbd\x03\x9c\x03\x81\x03^\x03@\x03\r\x03\xdb\x02\xa8\x02y\x02D\x02\r\x02\xe2\x01\xb2\x01\x86\x01Y\x01+\x01\xfa\x00\xd6\x00\xb1\x00\x9a\x00\x7f\x00a\x00L\x002\x00\x1b\x00\x00\x00\xe0\xff\xb9\xff\x99\xfft\xffO\xff(\xff\x01\xff\xde\xfe\xb
arr_in = tfm.build_array(input_filepath=WAVE_OUTPUT_FILENAME, sample_rate_in=RATE)
# Out:
# This install of SoX cannot process .wav files.

# %%
import subprocess
subprocess.run(["cowsay", "hello"])
# Out:
# {'COMMAND_MODE': 'unix2003', 'DISPLAY': '/private/tmp/com.apple.launchd.dWumMmcUqK/org.xquartz:0', 'EDITOR': 'nano', 'HOME': '/Users/ooj', 'HOMEBREW_CELLAR': '/opt/homebrew/Cellar', 'HOMEBREW_PREFIX': '/opt/homebrew', 'HOMEBREW_REPOSITORY': '/opt/homebrew', 'INFOPATH': '/opt/homebrew/share/info:', 'LESS': '-R', 'LOGNAME': 'ooj', 'LSCOLORS': 'Gxfxcxdxbxegedabagacad', 'LaunchInstanceID': '09741083-6444-4F47-B994-3EE660F6B043', 'MallocNanoZone': '0', 'NIX_PATH': '/Users/ooj/.nix-defexpr/channels:nixpkgs=flake:nixpkgs:/nix/var/nix/profiles/per-user/root/channels', 'NIX_PROFILES': '/nix/var/nix/profiles/default /run/current-system/sw /etc/profiles/per-user/ooj /Users/ooj/.nix-profile', 'NIX_REMOTE': 'daemon', 'NIX_SSL_CERT_FILE': '/etc/ssl/certs/ca-certificates.crt', 'NIX_USER_PROFILE_DIR': '/nix/var/nix/profiles/per-user/ooj', 'OLDPWD': '/', 'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined', 'P9K_SSH': '0', 'PAGER': 'cat', 'PATH': '/Users/ooj/Dev/HKUST/COMP4531/volora/.venv/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/Users/ooj/.nix-profile/bin:/etc/profiles/per-user/ooj/bin:/run/current-system/sw/bin:/nix/var/nix/profiles/default/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Users/ooj/.zsh/plugins/powerlevel10k', 'PWD': '/', 'SECURITYSESSIONID': '186af', 'SHELL': '/bin/zsh', 'SHLVL': '0', 'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.D3kTIzSl8B/Listeners', 'TERMINFO_DIRS': '/Users/ooj/.nix-profile/share/terminfo:/etc/profiles/per-user/ooj/share/terminfo:/run/current-system/sw/share/terminfo:/nix/var/nix/profiles/default/share/terminfo:/usr/share/terminfo', 'TMPDIR': '/var/folders/z3/ypy2s2tx4tb6htkr0d0g2fpm0000gn/T/', 'USER': 'ooj', 'VSCODE_AMD_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess', 'VSCODE_CODE_CACHE_PATH': '/Users/ooj/Library/Application Support/Code/CachedData/f1e16e1e6214d7c44d078b1f0607b2388f29d729', 'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost', 'VSCODE_CWD': '/', 'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true', 'VSCODE_IPC_HOOK': '/Users/ooj/Library/Application Support/Code/1.91-main.sock', 'VSCODE_NLS_CONFIG': '{"locale":"en","osLocale":"en-hk","availableLanguages":{},"_languagePackSupport":true}', 'VSCODE_PID': '79122', 'XDG_CONFIG_DIRS': '/Users/ooj/.nix-profile/etc/xdg:/etc/profiles/per-user/ooj/etc/xdg:/run/current-system/sw/etc/xdg:/nix/var/nix/profiles/default/etc/xdg', 'XDG_DATA_DIRS': '/Users/ooj/.nix-profile/share:/etc/profiles/per-user/ooj/share:/run/current-system/sw/share:/nix/var/nix/profiles/default/share', 'XPC_FLAGS': '0x0', 'XPC_SERVICE_NAME': 'application.com.microsoft.VSCode.98246471.98246477', '_': '/Users/ooj/Dev/HKUST/COMP4531/volora/.venv/bin/python', '__CFBundleIdentifier': 'com.microsoft.VSCode', '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0', '__HM_SESS_VARS_SOURCED': '1', '__HM_ZSH_SESS_VARS_SOURCED': '1', '__NIX_DARWIN_SET_ENVIRONMENT_DONE': '1', 'ELECTRON_RUN_AS_NODE': '1', 'DEBUG': 'WARN', 'VSCODE_L10N_BUNDLE_LOCATION': '', 'PLATFORMIO_CALLER': 'vscode', 'LC_ALL': 'en_US.UTF-8', 'PLATFORMIO_IDE': '3.3.4', 'PLATFORMIO_PATH': '/Users/ooj/.platformio/penv/bin:/Users/ooj/.platformio/penv:/Users/ooj/.platformio/python3/bin:/opt/homebrew/bin:/opt/homebrew/sbin:/Users/ooj/.nix-profile/bin:/etc/profiles/per-user/ooj/bin:/run/current-system/sw/bin:/nix/var/nix/profiles/default/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Users/ooj/.zsh/plugins/powerlevel10k', 'NO_PROXY': '127.0.0.1', 'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1', 'APPLICATIONINSIGHTS_CONFIGURATION_CONTENT': '{}', 'PYTHONUNBUFFERED': '1', 'VIRTUAL_ENV': '/Users/ooj/Dev/HKUST/COMP4531/volora/.venv', 'PYTHONIOENCODING': 'utf-8', 'VIRTUAL_ENV_PROMPT': '(.venv) ', 'PS1': '(.venv) ', 'LC_CTYPE': 'UTF-8', 'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1', 'PYTHON_FROZEN_MODULES': 'on', 'PYDEVD_USE_FRAME_EVAL': 'NO', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'FORCE_COLOR': '1', 'CLICOLOR_FORCE': '1', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[37], line 5
#       3 env = os.environ.copy()
#       4 print(env)
# ----> 5 subprocess.run(["cowsay", "hello"])
#
# File /nix/store/k9sy54316qsvl2j9prq0b88z3q9ah266-python3-3.11.12/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File /nix/store/k9sy54316qsvl2j9prq0b88z3q9ah266-python3-3.11.12/lib/python3.11/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /nix/store/k9sy54316qsvl2j9prq0b88z3q9ah266-python3-3.11.12/lib/python3.11/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1953     err_msg = os.strerror(errno_num)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#    1957     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cowsay'
