# %%
import pyaudio
import wave

# %%
CHUNK = 1024
FORMAT = pyaudio.paInt16 # 16 bits per sample
CHANNELS = 1
RATE = 44100 # 44.1k samples/sec # try 500 for 8k bitrate
# RATE = 500
RECORD_SECONDS = 3 # 3s
WAVE_OUTPUT_FILENAME = "input.wav"

# total samples = RATE * RECORD_SECONDS = 44100 * 3 = 132300
# total bits = total samples * 16 bits = 132300 * 16 = 2116800
# bitrate = total bits / total seconds = 2116800 / 3 = 705600

# %%
p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("* done recording")

stream.stop_stream()
stream.close()
p.terminate()
# Out:
# * recording
# * done recording

# %%
print(frames)
print(len(frames))
# print number of bits
print(len(frames[0]))
# print number of bytes
print(len(frames[0]) / 8)
# Out:
# [b'\x00\x00\x00\x00\x00\x00\x00\x00\x02\x00\t\x00\x1d\x00H\x00w\x00i\x00,\x009\x00{\x00}\x00s\x00\x89\x00i\x00\x10\x00\x03\x00`\x00\x84\x00N\x002\x00L\x00p\x00q\x00X\x00R\x00o\x00\x94\x00\xbc\x00\xe6\x00\xca\x00e\x00\x1d\x00%\x003\x00\x16\x00#\x00G\x00B\x00\x15\x00\xf9\xff\xde\xff\xbb\xff\xe8\xff3\x00;\x00\x1c\x00\x18\x00\x15\x00\xff\xff\xf8\xff\xf1\xff\xef\xff\n\x00\x16\x00\x01\x00\x08\x00/\x003\x00\x1f\x00\x15\x00\xff\xff\xe0\xff\xd0\xff\xd1\xff\xe0\xff\xfe\xff\x0f\x00\xfe\xff\xe9\xff\xfe\xff1\x00?\x00\x1c\x00\x0b\x00,\x00L\x00V\x00Z\x00r\x00\x93\x00\x8d\x00u\x00d\x00V\x00Y\x00U\x00=\x009\x00M\x00W\x00S\x00L\x00D\x001\x001\x00P\x00[\x00C\x001\x00A\x00\\\x00m\x00[\x00)\x00\xfe\xff\xfc\xff \x00<\x00K\x00D\x00L\x00j\x00j\x00N\x002\x00\x1f\x00\x15\x00\x1f\x00/\x007\x00\x1c\x00\xeb\xff\xc6\xff\xa9\xff\x96\xff\x9f\xff\xbb\xff\xcd\xff\xca\xff\xba\xff\xa5\xff\x9c\xff\x9e\xff\x94\xff\x95\xff\xb8\xff\xcf\xff\xc1\xff\x95\xffy\xff\x8f\xff\xbd\xff\xd7\xff\xdf\xff\xe1\xff\xca\xff\xbb\xff\xb5\xff\xbc\xff\xba\xff\xae\xff\xa4\xff\xa2\xff\xbc\xff\xc2\xff\xaf\xff\xa6\xff\x9b\xff\x8d\xff\x99\xff\xb5\xff\xb8\xff\xae\xff\xac\xff\x9d\xffz\xffe\xffn\xffw\xff\x9a\xff\xd8\xff\xe6\xff\xc5\xff\xaa\xff\x95\xff\x93\xff\xa1\xff\xa2\xff\x94\xff\x95\xff\x9f\xff\x9b\xff\xa4\xff\xb5\xff\xc2\xff\xc0\xff\xbe\xff\xc8\xff\xc9\xff\xc4\xff\xbf\xff\